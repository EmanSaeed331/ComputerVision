# %%
#Creat a 5 by 5 array where every number is a 10

import numpy as np
arr = (np.ones(shape=(5,5)))*10

# %%
arr
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
#Create a random numbers 
np.random.seed(101)
arr = np.random.randint(0,100,10)

# %%
arr
# Out:
# array([95, 11, 81, 70, 63, 87, 75,  9, 77, 40])

# %%
arr.argmax()
# Out:
# 0

# %%
arr.argmin()
# Out:
# 7

# %%
 #TASK : READ THE PUPPY IMAGE
from PIL import Image
pic = Image.open('English Lab Puppy (1)_0.png')

# %%
#TAKS CONVERT THE IMAGE TO NUMBY ARRAY
pic_arr = np.asarray(pic)
pic_arr
# Out:
# array([[[250, 249, 254],
#         [251, 250, 254],
#         [251, 250, 255],
#         ...,
#         [ 58,  55,  76],
#         [ 50,  47,  69],
#         [ 43,  38,  60]],
#
#        [[251, 250, 254],
#         [251, 250, 254],
#         [251, 250, 255],
#         ...,
#         [ 57,  54,  74],
#         [ 51,  48,  70],
#         [ 46,  41,  63]],
#
#        [[250, 250, 254],
#         [251, 250, 254],
#         [251, 250, 255],
#         ...,
#         [ 58,  55,  73],
#         [ 52,  48,  71],
#         [ 47,  42,  65]],
#
#        ...,
#
#        [[144, 156, 121],
#         [138, 153, 116],
#         [130, 150, 101],
#         ...,
#         [121, 131, 104],
#         [120, 126, 100],
#         [109, 117,  91]],
#
#        [[140, 151, 111],
#         [134, 147, 107],
#         [125, 146, 100],
#         ...,
#         [114, 128,  62],
#         [114, 125,  63],
#         [109, 118,  56]],
#
#        [[136, 148, 102],
#         [128, 141, 100],
#         [122, 142,  99],
# ...

# %%
#FINAL TAKS : USE SLICING to SET the red and green channels of the picture to 0
import matplotlib.pyplot as plt
pic_red = pic_arr.copy()

# %%
pic_red[:,:,0]
# Out:
# array([[250, 251, 251, ...,  58,  50,  43],
#        [251, 251, 251, ...,  57,  51,  46],
#        [250, 251, 251, ...,  58,  52,  47],
#        ...,
#        [144, 138, 130, ..., 121, 120, 109],
#        [140, 134, 125, ..., 114, 114, 109],
#        [136, 128, 122, ..., 111, 114, 111]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,1],cmap ='gray')

# %%
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[:,:,2])

# %% [markdown]
# # GRID DETECTION

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('flat_chess2.jpg')

# %%
plt.imshow(flat_chess)

# %%
found,corners = cv2.findChessboardCorners(flat_chess,(7,7))

# %%
found
# Out:
# False

# %%
corners

# %%
cv2.drawChessboardCorners(flat_chess,(7,7),corners,found)
# Out:
# array([[[203, 196, 199],
#         [221, 216, 218],
#         [194, 195, 199],
#         ...,
#         [193, 201, 214],
#         [197, 205, 218],
#         [203, 211, 224]],
#
#        [[204, 197, 204],
#         [219, 217, 223],
#         [199, 202, 207],
#         ...,
#         [208, 216, 229],
#         [211, 219, 232],
#         [218, 226, 239]],
#
#        [[197, 195, 207],
#         [212, 214, 225],
#         [192, 201, 211],
#         ...,
#         [194, 202, 215],
#         [198, 206, 219],
#         [204, 212, 225]],
#
#        ...,
#
#        [[122, 139, 160],
#         [119, 136, 157],
#         [ 88, 107, 128],
#         ...,
#         [123, 139, 152],
#         [135, 151, 164],
#         [137, 153, 166]],
#
#        [[125, 142, 163],
#         [124, 141, 162],
#         [ 96, 115, 136],
#         ...,
#         [127, 143, 156],
#         [138, 154, 167],
#         [141, 157, 170]],
#
#        [[127, 144, 165],
#         [128, 145, 166],
#         [103, 122, 143],
#         ...,
#         [129, 145, 158],
#         [140, 156, 169],
#         [143, 159, 172]]], dtype=uint8)

# %%
plt.imshow(flat_chess)

# %%
found,corners = cv2.findChessboardCorners(flat_chess,(7,7))

# %%
found
# Out:
# False

# %%
dots = cv2.imread('dot_grid.jpg')

# %%
plt.imshow(dots)

# %%
found,corners = cv2.findCirclesGrid(dots,(10,10),cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 399.5412 ,  799.4486 ]],
#
#        [[ 449.37982,  799.33826]],
#
#        [[ 499.59146,  799.4125 ]],
#
#        [[ 549.4723 ,  799.4335 ]],
#
#        [[ 599.49274,  799.4539 ]],
#
#        [[ 649.4888 ,  799.43256]],
#
#        [[ 699.5218 ,  799.43427]],
#
#        [[ 749.5269 ,  799.4335 ]],
#
#        [[ 799.43207,  799.46   ]],
#
#        [[ 849.35876,  799.2665 ]],
#
#        [[ 399.54404,  849.53656]],
#
#        [[ 449.4001 ,  849.5947 ]],
#
#        [[ 499.56818,  849.52344]],
#
#        [[ 549.48175,  849.53467]],
#
#        [[ 599.494  ,  849.53314]],
#
#        [[ 649.4999 ,  849.5338 ]],
#
#        [[ 699.5053 ,  849.5347 ]],
#
#        [[ 749.52374,  849.5326 ]],
#
#        [[ 799.3341 ,  849.4873 ]],
#
#        [[ 849.5513 ,  849.67114]],
#
#        [[ 399.55692,  899.4603 ]],
#
#        [[ 449.45657,  899.4503 ]],
#
#        [[ 499.57504,  899.4378 ]],
#
#        [[ 549.4753 ,  899.45355]],
#
#        [[ 599.48193,  899.4505 ]],
#
#        [[ 649.5045 ,  899.462  ]],
#
#        [[ 699.51434,  899.4569 ]],
#
#        [[ 749.5427 ,  899.45465]],
#
#        [[ 799.5699 ,  899.59735]],
#
#        [[ 849.52716,  899.45465]],
#
#        [[ 399.5276 ,  949.54614]],
#
#        [[ 449.46466,  949.5531 ]],
#
#        [[ 499.58115,  949.56537]],
#
#        [[ 549.4918 ,  949.54395]],
#
#        [[ 599.4739 ,  949.561  ]],
#
#        [[ 649.48987,  949.54425]],
#
#        [[ 699.51434,  949.5683 ]],
#
#        [[ 749.5158 ,  949.55164]],
#
#        [[ 799.448  ,  949.56635]],
#
#        [[ 849.5054 ,  949.5425 ]],
#
#        [[ 399.53787,  999.448  ]],
#
#        [[ 449.46844,  999.4372 ]],
#
#        [[ 499.56418,  999.43243]],
#
#        [[ 549.5001 ,  999.44995]],
#
#        [[ 599.49384,  999.46564]],
#
#        [[ 649.48016,  999.4755 ]],
#
#        [[ 699.51337,  999.4412 ]],
#
#        [[ 749.53235,  999.4487 ]],
#
#        [[ 799.4266 ,  999.4419 ]],
#
#        [[ 849.5046 ,  999.44244]],
#
#        [[ 399.52805, 1049.5461 ]],
#
#        [[ 449.4722 , 1049.5632 ]],
#
#        [[ 499.5726 , 1049.5295 ]],
#
#        [[ 549.4845 , 1049.5436 ]],
#
#        [[ 599.48145, 1049.5463 ]],
#
#        [[ 649.49976, 1049.556  ]],
#
#        [[ 699.5076 , 1049.5255 ]],
#
#        [[ 749.5152 , 1049.5532 ]],
#
#        [[ 799.4419 , 1049.5326 ]],
#
#        [[ 849.5194 , 1049.5468 ]],
#
#        [[ 399.5631 , 1099.4652 ]],
#
#        [[ 449.46512, 1099.4963 ]],
#
#        [[ 499.5681 , 1099.45   ]],
#
#        [[ 549.4837 , 1099.4717 ]],
#
#        [[ 599.4815 , 1099.4706 ]],
#
#        [[ 649.5022 , 1099.4796 ]],
#
#        [[ 699.5029 , 1099.4496 ]],
#
#        [[ 749.52563, 1099.4852 ]],
#
#        [[ 799.41394, 1099.4725 ]],
#
#        [[ 849.5248 , 1099.4672 ]],
#
#        [[ 399.53442, 1149.574  ]],
#
#        [[ 449.4644 , 1149.5656 ]],
#
#        [[ 499.42752, 1149.472  ]],
#
#        [[ 549.4809 , 1149.5619 ]],
#
#        [[ 599.48334, 1149.5808 ]],
#
#        [[ 649.4937 , 1149.5468 ]],
#
#        [[ 699.5159 , 1149.5651 ]],
#
#        [[ 749.527  , 1149.5552 ]],
#
#        [[ 799.42584, 1149.5692 ]],
#
#        [[ 849.52185, 1149.5621 ]],
#
#        [[ 399.51315, 1199.4661 ]],
#
#        [[ 449.35413, 1199.3273 ]],
#
#        [[ 499.5532 , 1199.5173 ]],
#
#        [[ 549.4733 , 1199.4746 ]],
#
#        [[ 599.46277, 1199.483  ]],
#
#        [[ 649.4884 , 1199.4775 ]],
#
#        [[ 699.5168 , 1199.4613 ]],
#
#        [[ 749.54047, 1199.4791 ]],
#
#        [[ 799.624  , 1199.4585 ]],
#
#        [[ 849.65735, 1199.4731 ]],
#
#        [[ 399.53497, 1249.4836 ]],
#
#        [[ 449.52762, 1249.4906 ]],
#
#        [[ 499.56577, 1249.462  ]],
#
#        [[ 549.49225, 1249.4701 ]],
#
#        [[ 599.495  , 1249.4987 ]],
#
#        [[ 649.4941 , 1249.4768 ]],
#
#        [[ 699.50244, 1249.48   ]],
#
#        [[ 749.5218 , 1249.4792 ]],
#
#        [[ 799.4384 , 1249.4788 ]],
#
#        [[ 849.6865 , 1249.6265 ]]], dtype=float32)

# %%
cv2.drawChessboardCorners(dots,(10,10),corners,found)
# Out:
# array([[[47, 47, 47],
#         [66, 66, 66],
#         [33, 33, 33],
#         ...,
#         [50, 50, 50],
#         [54, 54, 54],
#         [60, 60, 60]],
#
#        [[56, 56, 56],
#         [57, 57, 57],
#         [45, 45, 45],
#         ...,
#         [45, 45, 45],
#         [45, 45, 45],
#         [47, 47, 47]],
#
#        [[33, 33, 33],
#         [42, 42, 42],
#         [52, 52, 52],
#         ...,
#         [66, 66, 66],
#         [60, 60, 60],
#         [47, 47, 47]],
#
#        ...,
#
#        [[52, 52, 52],
#         [52, 52, 52],
#         [48, 48, 48],
#         ...,
#         [51, 51, 51],
#         [51, 51, 51],
#         [51, 51, 51]],
#
#        [[53, 53, 53],
#         [53, 53, 53],
#         [48, 48, 48],
#         ...,
#         [51, 51, 51],
#         [51, 51, 51],
#         [51, 51, 51]],
#
#        [[50, 50, 50],
#         [56, 56, 56],
#         [51, 51, 51],
#         ...,
#         [51, 51, 51],
#         [51, 51, 51],
#         [51, 51, 51]]], dtype=uint8)

# %%
plt.imshow(dots)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
"""
- we read image from image read function by using opencv.read('download.jpeg')
- we give the path of the image to read it .
"""

img  = cv2.imread('download.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 8, 15,  8],
#         [ 8, 15,  8],
#         [ 9, 16,  9],
#         ...,
#         [17, 21, 16],
#         [17, 21, 16],
#         [17, 21, 16]],
#
#        [[ 8, 15,  8],
#         [ 9, 16,  9],
#         [ 9, 16,  9],
#         ...,
#         [17, 21, 16],
#         [17, 21, 16],
#         [17, 21, 16]],
#
#        [[ 9, 16,  9],
#         [ 9, 16,  9],
#         [10, 17, 10],
#         ...,
#         [18, 22, 17],
#         [18, 22, 17],
#         [18, 22, 17]],
#
#        ...,
#
#        [[ 7,  6,  2],
#         [ 7,  6,  2],
#         [ 8,  8,  2],
#         ...,
#         [27, 26, 22],
#         [27, 26, 22],
#         [27, 26, 22]],
#
#        [[ 7,  6,  2],
#         [ 7,  6,  2],
#         [ 8,  8,  2],
#         ...,
#         [23, 22, 18],
#         [23, 22, 18],
#         [23, 22, 18]],
#
#        [[ 7,  6,  2],
#         [ 7,  6,  2],
#         [ 8,  8,  2],
#         ...,
#         [19, 18, 14],
#         [19, 18, 14],
#         [19, 18, 14]]], dtype=uint8)

# %%
#img = cv2.imread('wrong/path/')

# %%
type(img)
# Out:
# NoneType

# %%
img.shape
# Out:
# (183, 276, 3)

# %%
plt.imshow(img)

# %%
#MATPLOTLIB --> RED GREEN BLUUE 
#OPENCV ---> BLUE GREEN RED

# %%
fixed_image=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_image)

# %%
#READ IMAGE with gray scale 
img_gray = cv2.imread('download.jpeg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
img_gray.shape
# Out:
# (183, 276)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
#Resizing the image scaling.
plt.imshow(fixed_image)

# %%
fixed_image.shape
# Out:
# (183, 276, 3)

# %%
new_img = cv2.resize(fixed_image,(100,100))

# %%
plt.imshow(new_img)

# %%
#Resize by ratio
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fixed_image,(0,0),fixed_image,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (92, 138, 3)

# %%
#flip images along the horizontal  or Vertical axis.
new_img = cv2.flip(fixed_image , 0)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fixed_image,1)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fixed_image,-1)

# %%
plt.imshow(new_img)

# %%
type(fixed_image)
# Out:
# numpy.ndarray

# %%
#Generating a new image with a name "totally_new.jpeg"
cv2.imwrite('totally_new.jpeg',fixed_image)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax  = fig.add_subplot(111)
ax.imshow(fixed_image)
